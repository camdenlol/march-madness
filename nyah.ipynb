# %% [markdown]
# <a href="https://colab.research.google.com/github/camdenlol/march-madness/blob/main/nyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/camdenlol/march-madness/main/mrachie%20madnoss%20graphie.csv')

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install squarify
import squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
df
# Out:
#      seeding matchup  opponent
# 0     No. 9 vs No. 8        79
# 1    No. 11 vs No. 6        60
# 2    No. 10 vs No. 7        60
# 3    No. 12 vs No. 5        51
# 4     No. 5 vs No. 4        37
# 5     No. 6 vs No. 3        32
# 6    No. 13 vs No. 4        30
# 7     No. 2 vs No. 1        29
# 8     No. 7 vs No. 2        27
# 9     No. 3 vs No. 2        24
# 10    No. 4 vs No. 1        22
# 11   No. 14 vs No. 3        22
# 12   No. 11 vs No. 3        19
# 13   No. 10 vs No. 2        19
# 14    No. 8 vs No. 1        17
# 15   No. 15 vs No. 2        11
# 16    No. 3 vs No. 1        11
# 17   No. 12 vs No. 4        11
# 18    No. 5 vs No. 1        10
# 19    No. 6 vs No. 2         8
# 20    No. 7 vs No. 3         7
# 21    No. 9 vs No. 1         6
# 22    No. 8 vs No. 4         6
# 23    No. 8 vs No. 2         6
# 24    No. 5 vs No. 2         5
# 25    No. 4 vs No. 2         5
# 26    No. 6 vs No. 1         5
# 27   No. 15 vs No. 7         4
# 28    No. 4 vs No. 3         4
# 29    No. 7 vs No. 4         4
# 30   No. 11 vs No. 7         4
# 31   No. 11 vs No. 1         4
# 32   No. 11 vs No. 2         3
# 33  No. 13 vs No. 12         3
# 34   No. 10 vs No. 3         3
# 35   No. 13 vs No. 5         3
# 36    No. 8 vs No. 5         3
# 37   No. 10 vs No. 6         3
# 38    No. 6 vs No. 4         3
# 39   No. 16 vs No. 1         2
# 40    No. 9 vs No. 4         2
# 41    No. 9 vs No. 5         2
# 42  No. 11 vs No. 10         2
# 43    No. 8 vs No. 7         2
# 44    No. 7 vs No. 6         2
# 45   No. 14 vs No. 6         2
# 46    No. 9 vs No. 3         1
# 47   No. 11 vs No. 9         1
# 48   No. 15 vs No. 3         1
# 49   No. 12 vs No. 8         1
# 50    No. 9 vs No. 2         1
# 51    No. 7 vs No. 1         1
# 52   No. 10 vs No. 1         1
# 53    No. 5 vs No. 3         1
# 54    No. 8 vs No. 6         1

# %%
df.columns
# Out:
# Index(['seeding matchup', 'opponent'], dtype='object')

# %%
df.plot(kind='bar', title='Most Occuring March Madness Upsets', ylabel= 'Times Occurred', xlabel= 'seeding matchup', figsize=(11,10))
# Out:
# <Axes: title={'center': 'Most Occuring March Madness Upsets'}, xlabel='seeding matchup', ylabel='Times Occurred'>

# %% [markdown]
# MATPLOT LIB RRRAAAAAAAAAAAAAAAAAHHHHHH

# %%
labels = df['seeding matchup']
sizes = df['opponent']

# %%
plt.figure(figsize=(10, 6))
squarify.plot(sizes=sizes, label=labels, alpha=0.6)
plt.axis('off')
plt.show()
